# %% [markdown]
# # 🎓 Exercices — Fondamentaux de l'IA
#
# Ce notebook contient des exercices pratiques pour renforcer votre compréhension des concepts fondamentaux de l'Intelligence Artificielle.
#
# ## Instructions
# - Complétez les cellules marquées `# TODO: add your code here`
# - Exécutez chaque cellule pour vérifier vos résultats
# - Des tests automatiques valideront vos réponses
#
# ## 📚 Concepts couverts
# 1. Domaines d'application de l'IA
# 2. Systèmes experts et règles logiques
# 3. Différences entre approches symboliques et statistiques
# 4. Histoire et cycles de l'IA

# %%
# 🎯 Exercice 1: Domaines d'application de l'IA
# Listez au moins 5 domaines où l'IA a un impact significatif

applications = [
    # TODO: add your code here
    # Exemples: "santé", "transport", "finance", ...
]

# Test automatique
print(f"Vous avez listé {len(applications)} domaines:")
for i, app in enumerate(applications, 1):
    print(f"{i}. {app}")

# Vérification
assert len(applications) >= 3, "Vous devez lister au moins 3 domaines"
print("✅ Test réussi!")

# %%
# 🤖 Exercice 2: Système expert simple
# Implémentez un système de diagnostic médical basé sur des règles

def diagnostic_medical(temperature, maux_de_tete, toux, mal_gorge):
    """
    Système expert simple pour diagnostic médical
    
    Règles:
    - Si température > 38°C ET maux_de_tête → suspicion_fièvre
    - Si suspicion_fièvre ET toux → possibilité_grippe  
    - Si suspicion_fièvre ET mal_gorge → possibilité_angine
    - Sinon → état_normal
    
    Args:
        temperature (float): Température corporelle en °C
        maux_de_tete (bool): Présence de maux de tête
        toux (bool): Présence de toux
        mal_gorge (bool): Présence de mal de gorge
    
    Returns:
        str: Diagnostic suggéré
    """
    # TODO: add your code here
    # Implémentez les règles de diagnostic
    
    return "état_normal"  # placeholder

# Tests
print("Tests du système expert:")
print(f"Test 1: {diagnostic_medical(39.1, True, True, False)}")   # → possibilité_grippe
print(f"Test 2: {diagnostic_medical(39.5, True, False, True)}")   # → possibilité_angine  
print(f"Test 3: {diagnostic_medical(37.2, False, False, False)}") # → état_normal

# Test automatique
# result1 = diagnostic_medical(39.1, True, True, False)
# assert "grippe" in result1.lower(), f"Attendu 'grippe', obtenu '{result1}'"
# print("✅ Test système expert réussi!")

# %%
# 📊 Exercice 3: Comparaison approches symbolique vs statistique
# Analysez les avantages et inconvénients de chaque approche

def comparer_approches():
    """
    Créez un dictionnaire comparant les approches symbolique et statistique
    """
    comparison = {
        "symbolique": {
            "avantages": [
                # TODO: add your code here
                # Exemples: "explicabilité", "transparence", ...
            ],
            "inconvénients": [
                # TODO: add your code here
            ]
        },
        "statistique": {
            "avantages": [
                # TODO: add your code here
            ],
            "inconvénients": [
                # TODO: add your code here
            ]
        }
    }
    return comparison

# Test et affichage
comp = comparer_approches()
for approche, details in comp.items():
    print(f"\n🔍 Approche {approche.upper()}:")
    print(f"✅ Avantages: {', '.join(details['avantages'])}")
    print(f"❌ Inconvénients: {', '.join(details['inconvénients'])}")

# %%
# 📈 Exercice 4: Timeline de l'IA
# Ordonnez chronologiquement ces événements importants de l'IA

evenements = [
    "Test de Turing",
    "ChatGPT lancé", 
    "AlphaGo bat Lee Sedol",
    "Conférence de Dartmouth",
    "Deep Blue bat Kasparov",
    "Perceptron inventé",
    "ImageNet challenge",
    "Transformers architectures"
]

# TODO: Triez ces événements par ordre chronologique
# Créez une liste avec les événements dans l'ordre (du plus ancien au plus récent)
timeline_ordonnee = [
    # TODO: add your code here
]

print("🕰️ Timeline de l'IA (votre réponse):")
for i, event in enumerate(timeline_ordonnee, 1):
    print(f"{i}. {event}")

# Solution attendue (décommentez pour vérifier)
# solution = [
#     "Test de Turing",
#     "Conférence de Dartmouth", 
#     "Perceptron inventé",
#     "Deep Blue bat Kasparov",
#     "ImageNet challenge",
#     "AlphaGo bat Lee Sedol",
#     "Transformers architectures",
#     "ChatGPT lancé"
# ]

# %%
# 🎮 Exercice 5: Mini-projet - Système de recommandation simple
# Implémentez un système de recommandation basé sur des règles

def recommander_film(utilisateur_age, genres_preferes, note_minimum):
    """
    Système de recommandation de films basé sur des règles simples
    
    Args:
        utilisateur_age (int): Âge de l'utilisateur
        genres_preferes (list): Liste des genres préférés
        note_minimum (float): Note minimum acceptée (0-10)
    
    Returns:
        list: Liste de films recommandés
    """
    
    # Base de données simple de films
    films = [
        {"titre": "Inception", "genre": "sci-fi", "note": 8.8, "age_min": 13},
        {"titre": "The Avengers", "genre": "action", "note": 8.0, "age_min": 13},
        {"titre": "Toy Story", "genre": "animation", "note": 8.3, "age_min": 0},
        {"titre": "The Godfather", "genre": "drame", "note": 9.2, "age_min": 18},
        {"titre": "Finding Nemo", "genre": "animation", "note": 8.2, "age_min": 0},
        {"titre": "Interstellar", "genre": "sci-fi", "note": 8.6, "age_min": 13},
        {"titre": "The Dark Knight", "genre": "action", "note": 9.0, "age_min": 13}
    ]
    
    recommandations = []
    
    # TODO: Implémentez la logique de recommandation
    # Règles suggérées:
    # 1. Film adapté à l'âge (age_min <= utilisateur_age)
    # 2. Genre dans les préférences
    # 3. Note >= note_minimum
    # 4. Triez par note décroissante
    
    return recommandations

# Tests
print("🎬 Tests du système de recommandation:")
print("\nUtilisateur 1 (enfant):")
reco1 = recommander_film(8, ["animation"], 8.0)
print(f"Recommandations: {[film for film in reco1]}")

print("\nUtilisateur 2 (adulte sci-fi):")
reco2 = recommander_film(25, ["sci-fi", "action"], 8.5)
print(f"Recommandations: {[film for film in reco2]}")

# %% [markdown]
# ## 🎯 Solutions et explications
#
# ### Exercice 1 - Domaines d'application
# **Réponse type :**
# - Santé (diagnostic, découverte médicaments)
# - Transport (véhicules autonomes, optimisation trafic)
# - Finance (trading, détection fraude)
# - Éducation (tuteurs adaptatifs)
# - Environnement (prévision météo, optimisation énergie)
#
# ### Exercice 2 - Système expert
# **Logique de règles :**
# ```python
# if temperature > 38 and maux_de_tete:
#     if toux:
#         return "possibilité_grippe"
#     elif mal_gorge:
#         return "possibilité_angine"
#     else:
#         return "suspicion_fièvre"
# else:
#     return "état_normal"
# ```
#
# ### Exercice 3 - Comparaison d'approches
# **Symbolique :**
# - ✅ Explicabilité, contrôle précis, raisonnement logique
# - ❌ Rigidité, difficulté avec l'incertitude, maintenance complexe
#
# **Statistique :**
# - ✅ Adaptabilité, gestion incertitude, apprentissage automatique
# - ❌ Boîte noire, besoin de données, biais potentiels
#
# ### Exercice 4 - Timeline
# 1. Test de Turing (1950)
# 2. Conférence de Dartmouth (1956)
# 3. Perceptron inventé (1957)
# 4. Deep Blue bat Kasparov (1997)
# 5. ImageNet challenge (2012)
# 6. AlphaGo bat Lee Sedol (2016)
# 7. Transformers architectures (2017)
# 8. ChatGPT lancé (2022)
#
# ## 🚀 Pour aller plus loin
#
# 1. **Implémentez un système expert** plus complexe avec des règles probabilistes
# 2. **Créez une base de connaissances** pour un domaine qui vous intéresse
# 3. **Explorez l'histoire** d'un sous-domaine spécifique de l'IA
# 4. **Analysez les enjeux éthiques** d'une application IA concrète
